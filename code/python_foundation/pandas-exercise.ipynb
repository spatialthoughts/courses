# %%
import os
import pandas as pd

# %%
home_dir = os.path.expanduser('~')
print(home_dir)
# Out:
# /Users/ujaval

# %%
filename = 'cities5000.txt'
folder = 'Downloads/python_geospatial/'
path = os.path.join(home_dir, folder, filename)
print(path)
# Out:
# /Users/ujaval/Downloads/python_geospatial/cities5000.txt

# %%
column_names = ['geonameid', 'name', 'asciiname', 'alternatenames', 'latitude', 'longitude', 'feature class', 'feature code', 'country code', 'cc2', 'admin1 code', 'admin2 code', 'admin3 code', 'admin4 code', 'population', 'elevation', 'dem', 'timezone', 'modification date']
df = pd.read_csv(path, sep='\t', names=column_names)
df.head()
# Out:
#    geonameid                 name            asciiname  \
# 0    3039163  Sant Julià de Lòria  Sant Julia de Loria
# 1    3039678               Ordino               Ordino
# 2    3040051         les Escaldes         les Escaldes
# 3    3040132           la Massana           la Massana
# 4    3040686               Encamp               Encamp
#
#                                       alternatenames  latitude  longitude  \
# 0  San Julia,San Julià,Sant Julia de Loria,Sant J...  42.46372    1.49129
# 1  Ordino,ao er di nuo,orudino jiao qu,Ордино,オルデ...  42.55623    1.53319
# 2  Ehskal'des-Ehndzhordani,Escaldes,Escaldes-Engo...  42.50729    1.53414
# 3  La Macana,La Massana,La Maçana,La-Massana,la M...  42.54499    1.51483
# 4  Ehnkam,Encamp,en kan pu,enkanpu jiao qu,Энкам,...  42.53474    1.58014
#
#   feature class feature code country code  cc2 admin1 code admin2 code  \
# 0             P         PPLA           AD  NaN          06         NaN
# 1             P         PPLA           AD  NaN          05         NaN
# 2             P         PPLA           AD  NaN          08         NaN
# 3             P         PPLA           AD  NaN          04         NaN
# 4             P         PPLA           AD  NaN          03         NaN
#
#   admin3 code admin4 code  population  elevation   dem        timezone  \
# 0         NaN         NaN        8022        NaN   921  Europe/Andorra
# 1         NaN         NaN        3066        NaN  1296  Europe/Andorra
# 2         NaN         NaN       15853        NaN  1033  Europe/Andorra
# 3         NaN         NaN        7211        NaN  1245  Europe/Andorra
# 4         NaN         NaN       11223        NaN  1257  Europe/Andorra
#
#   modification date
# 0        2013-11-23
# 1        2018-10-26
# 2        2008-10-15
# 3        2008-10-15
# 4        2018-10-26

# %%
df.shape
# Out:
# (50118, 19)

# %%
country = 'IN'
india_df = df[(df['country code']==country) & (df['population'] > 1000000)].copy()
india_df.shape
# Out:
# (41, 19)

# %%
# %run ./distance.ipynb

# %%
india_df['distance'] = india_df.apply(lambda row: haversine_distance((77.56, 12.97), (row['longitude'], row['latitude'])), axis=1)
india_df['distance'] = india_df['distance'].apply(lambda x: '%.2f' % x)
display(india_df)
# Out:
#        geonameid           name      asciiname  \
# 19928    1253102  Visakhapatnam  Visakhapatnam
# 19971    1253405       Varanasi       Varanasi
# 19988    1253573       Vadodara       Vadodara
# 20089    1254361    Tirunelveli    Tirunelveli
# 20120    1254661          Thāne          Thane
# 20131    1254745           Teni           Teni
# 20188    1255364          Surat          Surat
# 20607    1258847         Rājkot         Rajkot
# 20668    1259229           Pune           Pune
# 20720    1259652         Pimpri         Pimpri
# 20779    1260086          Patna          Patna
# 20901    1261162    Nowrangapur    Nowrangapur
# 20963    1261731         Nashik         Nashik
# 21023    1262111      Najafgarh      Najafgarh
# 21033    1262180         Nagpur         Nagpur
# 21155    1263214         Meerut         Meerut
# 21318    1264527        Chennai        Chennai
# 21339    1264728       Ludhiāna       Ludhiana
# 21340    1264733        Lucknow        Lucknow
# 21679    1267995         Kanpur         Kanpur
# 21717    1268295         Kalyān         Kalyan
# 21875    1269515         Jaipur         Jaipur
# 21893    1269633       Jabalpur       Jabalpur
# 21907    1269743         Indore         Indore
# 21924    1269843      Hyderabad      Hyderabad
# 21993    1270396          Hāora          Haora
# 22063    1270926      Gorakhpur      Gorakhpur
# 22105    1271308      Ghāziābād      Ghaziabad
# 22186    1271951      Faridabad      Faridabad
# 22234    1272423       Dombivli       Dombivli
# 22333    1273294          Delhi          Delhi
# 22512    1275004        Kolkāta        Kolkata
# 22534    1275339         Mumbai         Mumbai
# 22605    1275841         Bhopāl         Bhopal
# 22786    1277333      Bengaluru      Bengaluru
# 22886    1278149     Aurangabad     Aurangabad
# 22967    1278710       Amritsar       Amritsar
# 23013    1278994      Allahābād      Allahabad
# 23054    1279233      Ahmedabad      Ahmedabad
# 23056    1279259           Agra           Agra
# 23132    6619347    Navi Mumbai    Navi Mumbai
#
#                                           alternatenames  latitude  longitude  \
# 19928  VTZ,Vaisakhapattanam,Vaisākhapattanam,Visak,Vi...  17.68009   83.20161
# 19971  Banaras,Banares,Banāras,Benares,Benarés,Kashi,...  25.31668   83.01041
# 19988  BDQ,Baroda,Vadodara,Vapadedara,ba luo da,badod...  22.29941   73.20812
# 20089  Nellai,Tinnevelli,Tinnevelly,Tinnevelly Juncti...   8.72742   77.68380
# 20120  Tanja,Tanna,Thana,Thane,Thāna,Thāne,tanh,tany,...  19.19704   72.96355
# 20131                            Teni,Theni,Tkheni,Тхени  10.01115   77.47772
# 20188  STV,Surat,Suratas,Surate,Sūrat,su la te,surata...  21.19594   72.83023
# 20607  RAJ,Radzhkot,Radzkot,Radzkotas,Radźkot,Radžkot...  22.29161   70.79322
# 20668  PNQ,Pona,Poona,Poune,Pun,Puna,Pune,Puneo,Puno,...  18.51957   73.85535
# 20720                                             Pimpri  18.62292   73.80696
# 20779  'Azimabad,New Patna,PAT,Patna,Patna New City,P...  25.59408   85.13563
# 20901                Nabarangapur,Nabarangpur,Nowrangpur  19.23114   82.54826
# 20963  ISK,Nashik,Nasik,Nasikas,Nasiko,Naszik,Našikas...  19.99727   73.79096
# 21023                               Najafgarh,Najafgarli  28.60922   76.97982
# 21033  Ajni,NAG,Nagpore,Nagpur,Nagpura,Nagpuras,Nankp...  21.14631   79.08491
# 21155  Meerut,Meerut City,Merath,Meratkh,Mirat,Mirata...  28.98002   77.70636
# 21318  Cenaj,Cenajo,Cenajus,Cenay,Cennai,Cennaj,Chehn...  13.08784   80.27847
# 21339  LUH,Ludhiana,Ludhijana,Ludhiāna,Ludkhijana,lud...  30.91204   75.85379
# 21340  LKO,Lakhnau,Lakkhnau,Lakkhnau shaary,Laknaou,L...  26.83928   80.92313
# 21679  Cawnpore,KNU,Kanpur,Kanpuras,Kanpwr,Kānpur,Kān...  26.46523   80.34975
# 21717                       Kal'jan,Kalyan,Kalyān,Кальян  19.24370   73.13554
# 21875  Caypur,Dzaipur,Dzaipuras,Dzajpur,Dzajpura,Dzha...  26.91962   75.78781
# 21893  Dzabalpur,Dzabalpuras,Dzhabalpur,Dzsabalpur,Dż...  23.16697   79.95006
# 21907  IDR,Indaur,Indor,Indore,Indore Madhya Pradesh,...  22.71792   75.83330
# 21924  Bhaganagar,HYD,Haidarabadas,Haiderabad,Hajdara...  17.38405   78.45636
# 21993  Haora,Haura,Hawrah,Howrah,Hāora,ha'ora,haura,হ...  22.57688   88.31857
# 22063                      Gorakhpur,Gorakpura,Горакпура  29.44768   75.67206
# 22105     Gaziabad,Ghaziabad,Ghazibad,Ghāziābād,Газиабад  28.66535   77.43915
# 22186  Faridabad,Faridabadas,Farīdābād,QNF,faridabado...  28.41124   77.31316
# 22234                                          Dombivali  19.21667   73.08333
# 22333  DEL,Daehli,Dehli,Dehlī,Delchi,Delhi,Delhio,Del...  28.65195   77.23149
# 22512  CCU,Calcuta,Calcutta,Calcutá,Calcúta,Caligarda...  22.56263   88.36304
# 22534  Asumumbay,BOM,Bombai,Bombaim,Bombaj,Bombay,Bom...  19.07283   72.88261
# 22605  BHO,Bhojpal,Bhopal,Bhopala,Bhopalas,Bhopalo,Bh...  23.25469   77.40289
# 22786  BLR,Ban'nkalor,Bangalor,Bangalora,Bangalore,Ba...  12.97194   77.59369
# 22886  Aurangabad,Aurangabad - aurangabada,Aurangabad...  19.87757   75.34226
# 22967  ATQ,Amricar,Amritsar,Amritsar - amritasara,Amr...  31.62234   74.87534
# 23013  Alahabadas,Alla Abba Habab,Allahabad,Allahabad...  25.44478   81.84322
# 23054  AMD,Achmentampant,Ahmadabad,Ahmadabadas,Ahmada...  23.02579   72.58727
# 23056  AGR,Agra,Agra - agara,Agra - आगरा,Lungsod ng A...  27.18333   78.01667
# 23132  Marathi  Maharashtra,Navi Moembaai,Navi Mumbai...  19.03681   73.01582
#
#       feature class feature code country code  cc2 admin1 code admin2 code  \
# 19928             P        PPLA2           IN  NaN          02         544
# 19971             P          PPL           IN  NaN          36         197
# 19988             P          PPL           IN  NaN          09         486
# 20089             P        PPLA2           IN  NaN          25         628
# 20120             P          PPL           IN  NaN          16         517
# 20131             P         PPLX           IN  NaN          25         624
# 20188             P          PPL           IN  NaN          09         492
# 20607             P          PPL           IN  NaN          09         476
# 20668             P          PPL           IN  NaN          16         521
# 20720             P          PPL           IN  NaN          16         521
# 20779             P         PPLA           IN  NaN          34         230
# 20901             P        PPLA2           IN  NaN          21         397
# 20963             P        PPLA2           IN  NaN          16         516
# 21023             P          PPL           IN  NaN          07         097
# 21033             P        PPLA2           IN  NaN          16         505
# 21155             P          PPL           IN  NaN          36         138
# 21318             P         PPLA           IN  NaN          25         603
# 21339             P          PPL           IN  NaN          23         041
# 21340             P         PPLA           IN  NaN          36         157
# 21679             P          PPL           IN  NaN          36         164
# 21717             P          PPL           IN  NaN          16         517
# 21875             P         PPLA           IN  NaN          24         110
# 21893             P          PPL           IN  NaN          35         451
# 21907             P          PPL           IN  NaN          35         439
# 21924             P         PPLA           IN  NaN          40         536
# 21993             P          PPL           IN  NaN          28         341
# 22063             P          PPL           IN  NaN          10         078
# 22105             P        PPLA2           IN  NaN          36         140
# 22186             P          PPL           IN  NaN          10         088
# 22234             P          PPL           IN  NaN          16         517
# 22333             P         PPLA           IN  NaN          07         NaN
# 22512             P         PPLA           IN  NaN          28         342
# 22534             P         PPLA           IN  NaN          16         NaN
# 22605             P         PPLA           IN  NaN          35         444
# 22786             P         PPLA           IN  NaN          19         572
# 22886             P        PPLA2           IN  NaN          16         515
# 22967             P          PPL           IN  NaN          23         049
# 23013             P          PPL           IN  NaN          36         175
# 23054             P          PPL           IN  NaN          09         474
# 23056             P        PPLA2           IN  NaN          36         146
# 23132             P         PPLX           IN  NaN          16         517
#
#       admin3 code admin4 code  population  elevation  dem      timezone  \
# 19928         NaN         NaN     1063178        NaN   24  Asia/Kolkata
# 19971         NaN         NaN     1164404        NaN   86  Asia/Kolkata
# 19988         NaN         NaN     1409476        NaN   46  Asia/Kolkata
# 20089         NaN         NaN     1435844        NaN   49  Asia/Kolkata
# 20120         NaN         NaN     1261517        NaN   23  Asia/Kolkata
# 20131         NaN         NaN     1034724        NaN  300  Asia/Kolkata
# 20188         NaN         NaN     2894504        NaN   20  Asia/Kolkata
# 20607         NaN         NaN     1177362        NaN  140  Asia/Kolkata
# 20668         NaN         NaN     2935744        NaN  554  Asia/Kolkata
# 20720         NaN         NaN     1284606        NaN  571  Asia/Kolkata
# 20779         NaN         NaN     1599920        NaN   53  Asia/Kolkata
# 20901         NaN         NaN     1220946        NaN  578  Asia/Kolkata
# 20963         NaN         NaN     1289497        NaN  584  Asia/Kolkata
# 21023         NaN         NaN     1365000        NaN  215  Asia/Kolkata
# 21033         NaN         NaN     2228018        NaN  319  Asia/Kolkata
# 21155         NaN         NaN     1223184        NaN  228  Asia/Kolkata
# 21318         NaN         NaN     4328063        NaN   14  Asia/Kolkata
# 21339         NaN         NaN     1545368        NaN  256  Asia/Kolkata
# 21340         NaN         NaN     2472011        NaN  126  Asia/Kolkata
# 21679         NaN         NaN     2823249        NaN  137  Asia/Kolkata
# 21717         NaN         NaN     1262255        NaN   10  Asia/Kolkata
# 21875         NaN         NaN     2711758        NaN  435  Asia/Kolkata
# 21893         NaN         NaN     1030168        NaN  416  Asia/Kolkata
# 21907         NaN         NaN     1837041        NaN  550  Asia/Kolkata
# 21924         NaN         NaN     3597816        NaN  515  Asia/Kolkata
# 21993         NaN         NaN     1027672        NaN    8  Asia/Kolkata
# 22063         NaN         NaN     1324570        NaN  218  Asia/Kolkata
# 22105         NaN         NaN     1199191        NaN  214  Asia/Kolkata
# 22186         NaN         NaN     1220229        NaN  209  Asia/Kolkata
# 22234         NaN         NaN     1193000        NaN   11  Asia/Kolkata
# 22333         NaN         NaN    10927986        NaN  227  Asia/Kolkata
# 22512         NaN         NaN     4631392        NaN   11  Asia/Kolkata
# 22534         NaN         NaN    12691836        NaN    8  Asia/Kolkata
# 22605         NaN         NaN     1599914        NaN  523  Asia/Kolkata
# 22786         NaN         NaN     5104047      920.0  914  Asia/Kolkata
# 22886         NaN         NaN     1016441        NaN  588  Asia/Kolkata
# 22967         NaN         NaN     1092450        NaN  244  Asia/Kolkata
# 23013         NaN         NaN     1073438        NaN   99  Asia/Kolkata
# 23054         NaN         NaN     3719710        NaN   56  Asia/Kolkata
# 23056         NaN         NaN     1430055        NaN  166  Asia/Kolkata
# 23132         NaN         NaN     2600000        NaN   14  Asia/Kolkata
#
#       modification date distance
# 19928        2019-09-05   632.87
# 19971        2019-05-07   645.45
# 19988        2014-10-13   548.69
# 20089        2017-08-27   102.04
# 20120        2019-03-29   539.90
# 20131        2017-08-02    71.68
# 20188        2020-04-04   574.26
# 20607        2017-03-17   801.44
# 20668        2015-06-04   438.75
# 20720        2014-10-13   444.85
# 20779        2018-12-14   863.45
# 20901        2014-10-14   566.75
# 20963        2014-10-13   460.81
# 21023        2019-07-18   387.38
# 21033        2019-10-22   249.83
# 21155        2015-05-06   380.43
# 21318        2019-09-05   302.29
# 21339        2017-03-07   493.92
# 21340        2015-11-11   469.40
# 21679        2015-08-08   420.97
# 21717        2014-10-13   521.97
# 21875        2019-09-05   406.82
# 21893        2014-10-14   344.75
# 21907        2014-10-14   314.12
# 21924        2014-10-10   142.53
# 21993        2014-10-14  1199.32
# 22063        2017-09-05   471.06
# 22105        2018-07-13   376.86
# 22186        2017-05-06   373.40
# 22234        2014-10-13   527.29
# 22333        2019-09-05   381.11
# 22512        2020-04-08  1204.16
# 22534        2019-09-05   547.46
# 22605        2020-04-08   248.18
# 22786        2019-09-05     3.75
# 22886        2019-03-29   304.86
# 22967        2015-11-08   573.56
# 23013        2020-01-17   534.30
# 23054        2019-09-05   621.49
# 23056        2016-10-17   337.27
# 23132        2018-12-04   532.88

# %%
output = os.path.join(home_dir, 'Downloads', 'output.csv')
print(output)
india_df.to_csv(output, index=False)
# Out:
# /Users/ujaval/Downloads/output.csv
