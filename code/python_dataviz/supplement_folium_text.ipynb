# %% [markdown]
# ### Displaying Text on Folium Maps
#
# Folium supports [DivIcon](https://python-visualization.github.io/folium/latest/reference.html#folium.features.DivIcon) markers for creating text-markers. Using this, we can render text on a folium map easily. The example below an example of rendering markers with airport codes.
#
# <img src='https://courses.spatialthoughts.com/images/python_dataviz/folium_text.png' width=600/>

# %%
import os
import folium
from folium import Figure
from folium.features import DivIcon
import json

# %%
sfo = (37.616, -122.386)
jfk = (40.645, -73.782)

# %%
fig = Figure(width=800, height=400)
m = folium.Map(location=[39.83, -98.58], zoom_start=4)

folium.Marker(
    sfo,
    popup='San Francisco International Airport',
    icon=DivIcon(
        icon_size=(150,36),
        icon_anchor=(0,0),
        html='<div style="font-size: 24pt">SFO</div>',
    )).add_to(m)

folium.Marker(
    jfk,
    popup='John F. Kennedy International Airport',
    icon=DivIcon(
        icon_size=(150,36),
        icon_anchor=(0,0),
        html='<div style="font-size: 24pt">JFK</div>',
    )).add_to(m)


fig.add_child(m)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_af66ea25645c7210f9ac08e953a71b79 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_af66ea25645c7210f9ac08e953a71b79&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_af66ea25645c7210f9ac08e953a71b79 = L.map(
#                 &quot;map_af66ea25645c7210f9ac08e953a71b79&quot;,
#                 {
#                     center: [39.83, -98.58],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3e4bc5e1a47dbdbc59aef2a6aa6361ae = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3e4bc5e1a47dbdbc59aef2a6aa6361ae.addTo(map_af66ea25645c7210f9ac08e953a71b79);
#
#
#             var marker_9315f9a7b2e01222f00759d29b76d61c = L.marker(
#                 [37.616, -122.386],
#                 {
# }
#             ).addTo(map_af66ea25645c7210f9ac08e953a71b79);
#
#
#             var div_icon_826b3653abca6636d25d32a8f41b8837 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 24pt\&quot;\u003eSFO\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [150, 36],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#         var popup_673e47f8d4a1425d6e552f3702fcd0ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f6197e2e31fe870b33584493f01ad81 = $(`&lt;div id=&quot;html_8f6197e2e31fe870b33584493f01ad81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;San Francisco International Airport&lt;/div&gt;`)[0];
#                 popup_673e47f8d4a1425d6e552f3702fcd0ff.setContent(html_8f6197e2e31fe870b33584493f01ad81);
#
#
#
#         marker_9315f9a7b2e01222f00759d29b76d61c.bindPopup(popup_673e47f8d4a1425d6e552f3702fcd0ff)
#         ;
#
#
#
#
#                 marker_9315f9a7b2e01222f00759d29b76d61c.setIcon(div_icon_826b3653abca6636d25d32a8f41b8837);
#
#
#             var marker_fd783ff1b958a447270dc29991780869 = L.marker(
#                 [40.645, -73.782],
#                 {
# }
#             ).addTo(map_af66ea25645c7210f9ac08e953a71b79);
#
#
#             var div_icon_553f55756c098b3d450c7a73edd86770 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 24pt\&quot;\u003eJFK\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [150, 36],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#         var popup_510ff414ea27cb6c627cb45c57510758 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d10695e78bd4b8e38c0fd1c4d62601b5 = $(`&lt;div id=&quot;html_d10695e78bd4b8e38c0fd1c4d62601b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;John F. Kennedy International Airport&lt;/div&gt;`)[0];
#                 popup_510ff414ea27cb6c627cb45c57510758.setContent(html_d10695e78bd4b8e38c0fd1c4d62601b5);
#
#
#
#         marker_fd783ff1b958a447270dc29991780869.bindPopup(popup_510ff414ea27cb6c627cb45c57510758)
#         ;
#
#
#
#
#                 marker_fd783ff1b958a447270dc29991780869.setIcon(div_icon_553f55756c098b3d450c7a73edd86770);
#
# &lt;/script&gt;
# &lt;/html&gt;" width="800" height="400"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %% [markdown]
# ----
