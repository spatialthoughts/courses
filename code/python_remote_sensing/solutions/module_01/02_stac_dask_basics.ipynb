# %% [markdown]
# ### Exercise
#
# The `items` variable contains a list of STAC Items returned by the query. The code below iterates through each item and print its metadata stored in the `properties`. Extract the Sentinel-2 Product ID stored in `s2:product_uri` peroperty and print a list of all image ids returned by the query.

# %%
for item in items:
  print(item.properties)

# %%
[item.properties['s2:product_uri'] for item in items]
# Out:
# ['S2B_MSIL2A_20231224T051229_N0510_R019_T44RPR_20231224T073519.SAFE',
#  'S2B_MSIL2A_20230418T050659_N0509_R019_T44RPR_20230418T074740.SAFE',
#  'S2B_MSIL2A_20230207T050959_N0509_R019_T44RPR_20230207T075036.SAFE',
#  'S2A_MSIL2A_20230403T050651_N0509_R019_T44RPR_20230403T090854.SAFE',
#  'S2A_MSIL2A_20230423T050651_N0509_R019_T44RPR_20230423T092849.SAFE',
#  'S2A_MSIL2A_20230304T050711_N0509_R019_T44RPR_20230304T085603.SAFE',
#  'S2A_MSIL2A_20231109T051021_N0509_R019_T44RPR_20231109T082500.SAFE',
#  'S2B_MSIL2A_20230607T050659_N0509_R019_T44RPR_20230607T074904.SAFE',
#  'S2B_MSIL2A_20231104T050959_N0509_R019_T44RPR_20231104T074504.SAFE',
#  'S2B_MSIL2A_20230617T050659_N0509_R019_T44RPR_20230617T074954.SAFE',
#  'S2A_MSIL2A_20231020T050831_N0509_R019_T44RPR_20231020T090601.SAFE',
#  'S2A_MSIL2A_20230513T050651_N0509_R019_T44RPR_20230513T090759.SAFE',
#  'S2B_MSIL2A_20231025T050859_N0509_R019_T44RPR_20231025T081556.SAFE',
#  'S2A_MSIL2A_20230413T050651_N0509_R019_T44RPR_20230413T104956.SAFE',
#  'S2A_MSIL2A_20230212T050931_N0509_R019_T44RPR_20230212T094700.SAFE',
#  'S2A_MSIL2A_20230324T050651_N0509_R019_T44RPR_20230324T085900.SAFE',
#  'S2B_MSIL2A_20231124T051119_N0509_R019_T44RPR_20231124T070051.SAFE',
#  'S2A_MSIL2A_20231209T051211_N0509_R019_T44RPR_20231209T081452.SAFE',
#  'S2A_MSIL2A_20231119T051111_N0509_R019_T44RPR_20231119T083500.SAFE',
#  'S2A_MSIL2A_20231010T050721_N0509_R019_T44RPR_20231010T091100.SAFE',
#  'S2A_MSIL2A_20230123T051111_N0509_R019_T44RPR_20230123T085404.SAFE',
#  'S2A_MSIL2A_20230602T050701_N0509_R019_T44RPR_20230602T090153.SAFE',
#  'S2B_MSIL2A_20230118T051139_N0509_R019_T44RPR_20230118T070008.SAFE',
#  'S2B_MSIL2A_20230408T050659_N0509_R019_T44RPR_20230408T074703.SAFE',
#  'S2A_MSIL2A_20230612T050701_N0509_R019_T44RPR_20230612T090900.SAFE',
#  'S2A_MSIL2A_20231129T051141_N0509_R019_T44RPR_20231129T080700.SAFE',
#  'S2A_MSIL2A_20231030T050931_N0509_R019_T44RPR_20231030T085159.SAFE',
#  'S2B_MSIL2A_20231114T051049_N0509_R019_T44RPR_20231114T065836.SAFE',
#  'S2A_MSIL2A_20230722T050701_N0509_R019_T44RPR_20230722T090056.SAFE',
#  'S2A_MSIL2A_20230222T050821_N0509_R019_T44RPR_20230222T092656.SAFE',
#  'S2B_MSIL2A_20231214T051219_N0510_R019_T44RPR_20231214T065231.SAFE',
#  'S2B_MSIL2A_20230528T050659_N0509_R019_T44RPR_20230528T074759.SAFE',
#  'S2B_MSIL2A_20230518T050659_N0509_R019_T44RPR_20230518T092654.SAFE',
#  'S2A_MSIL2A_20230930T050651_N0509_R019_T44RPR_20230930T091756.SAFE',
#  'S2B_MSIL2A_20231015T050759_N0509_R019_T44RPR_20231015T075113.SAFE',
#  'S2B_MSIL2A_20230309T050659_N0509_R019_T44RPR_20230309T091650.SAFE',
#  'S2A_MSIL2A_20230622T050701_N0509_R019_T44RPR_20230622T090956.SAFE',
#  'S2A_MSIL2A_20230113T051151_N0509_R019_T44RPR_20230113T080603.SAFE']
