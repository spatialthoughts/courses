# %%
import os
data_pkg_path = '../data'
filename = 'worldcities.csv'
path = os.path.join(data_pkg_path, filename)
print(path)
# Out:
# ../data/worldcities.csv

# %%
f = open(path, 'r', encoding='utf-8')
count = 0
for line in f:
    count += 1
f.close()
print(count)
# Out:
# 15494

# %% [markdown]
# Prompt for Claude AI
#
# ```
# give me python code  a file named data.prj with the following content
#
# GEOGCS["GCS_WGS_1984",
#     DATUM["D_WGS_1984",
#         SPHEROID["WGS_1984",6378137.0,298.257223563]],
#     PRIMEM["Greenwich",0.0],
#     UNIT["Degree",0.0174532925199433]]
# ```

# %%
content = """GEOGCS["GCS_WGS_1984",
    DATUM["D_WGS_1984",
        SPHEROID["WGS_1984",6378137.0,298.257223563]],
    PRIMEM["Greenwich",0.0],
    UNIT["Degree",0.0174532925199433]]"""

with open("data.prj", "w") as f:
    f.write(content)
